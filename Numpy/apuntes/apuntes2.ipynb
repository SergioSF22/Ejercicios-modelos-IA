# %% [markdown]
# # Operaciones matemáticas y trigonométricas: Raíz cuadrada, exponente y logaritmo

# %%
import numpy as np
from sklearn.metrics import root_mean_squared_error

"""
1- Crea dos vectores con 10 valores aleatorios int entre 30 y 60 (vector 1) y con 10 valores float del 0.1 al 9.9 (vector 2)
2- El primer vector se corresponderá con el valor real y e segundo vector con el valor presicho por el modelo. 
3- Calcula el RMSE con la función root_mean_squared_error de Scikit-learn y además también utilizando la fórmula tradicional.
4- Imprime el resultado de ambas formas.
5- ¿Hay diferencia entre los resultados?
"""
datos_reales = np.random.randint(30, 60, size=(10))
datos_predichos = np.random.uniform(0.1, 9.9, 10)
print(f"Datos reales: {datos_reales}")
print("Datos predichos: ", datos_predichos)

sk_rmse = root_mean_squared_error(datos_reales, datos_predichos)
print("-" * 50)
print(f"RSME mediante Scikit-learn (Porcentaje): {sk_rmse:.2f} %")
print(f"RSME mediante Scikit-learn: {sk_rmse}")

print("-" * 50)
rmse = np.sqrt(np.mean((datos_reales - datos_predichos) ** 2))
print(f"RMSE mediante fórmula (Porcentaje): {rmse:.2f} %")
print("RMSE mediante fórmula: ", rmse)
# No hay una diferencia apreciable entre los resultados
# Out:
# Datos reales: [34 32 41 37 51 56 32 30 32 34]
# Datos predichos:  [9.62277853 8.41935548 7.17294931 2.41265221 2.60946956 0.49624918
#  7.06449632 1.18673004 4.40549772 2.07684818]
# --------------------------------------------------
# RSME mediante Scikit-learn (Porcentaje): 34.85 %
# RSME mediante Scikit-learn: 34.85066361885396
# --------------------------------------------------
# RMSE mediante fórmula (Porcentaje): 34.85 %
# RMSE mediante fórmula:  34.85066361885396

# %% [markdown]
# # Ordenamiento

# %%
# Creamos una matriz de 3x3 con valores aleatorios entre 1 y 9
array_2d = np.random.randint(1, 10, size=(3, 3))
print("Matriz original:\n ", array_2d)

# Mediante la función seed() podemos dejar estáticos los valores aleatorios primeramente generados cada vez que volvemos a ejecutar el código
np.random.seed(42)

# Usando sort() ,que devuelve una copia del array pasado como parámetro, ordenamos el array
# Ordenamiento sobre filas (Por defecto)
sorted_rows = np.sort(array_2d, axis=1)
# Ordenamiento sobre columnas
sorted_columns = np.sort(array_2d, axis=0)
print("Matriz ordenada por filas:\n ", sorted_rows)
print("Matriz ordenada por columnas:\n ", sorted_columns)

# Ejemplo pero usando strings, realiza el ordenamiento por orden alfabético
palabras = np.array(
    ["CASA", "CASANOVA", "ANA", "ANDAMIO", "PERRO", "PÉRTIGA", "TUCÁN", "TUCUMÁN"]
)
palabras_ordenadas = np.sort(palabras)
print("Palabras ordenadas: ", palabras_ordenadas)
# Out:
# Matriz original:
#   [[7 1 4]
#  [4 5 7]
#  [7 4 7]]
# Matriz ordenada por filas:
#   [[1 4 7]
#  [4 5 7]
#  [4 7 7]]
# Matriz ordenada por columnas:
#   [[4 1 4]
#  [7 4 7]
#  [7 5 7]]
# Palabras ordenadas:  ['ANA' 'ANDAMIO' 'CASA' 'CASANOVA' 'PERRO' 'PÉRTIGA' 'TUCUMÁN' 'TUCÁN']

# %% [markdown]
# # BÚSQUEDAS Y FILTROS

# %%
# Array de ejemplo
array_1d = np.array([1, 5, 7, 3, 65, 2, 1, 32, 44, 55, 64, 21, 89])

# Devuelve el index del valor mas pequeño
min_index = np.argmin(array_1d)
print("Index del valor mas pequeño: ", min_index)

# Devuelve el index del valor mas grande
max_index = np.argmax(array_1d)
print("Index del valor mas grande: ", max_index)

# Filtrado mediante cualquier expresión booleana en la indexación
array_filtrado1 = array_1d[array_1d > 35]
print("Valores filtrados con indexación: ", array_filtrado1)

# Parecido al anterior pero devuelve los index en vez de los valores
array_filtrado2 = np.where(array_1d > 35)
print("Index de los valores filtrados: ", array_filtrado2)

# Ejemplo del uso de where()
edades = np.random.randint(0, 80, size=10)
print("Valores edades: ", edades)
edades_cladificadas = np.where(edades >= 37, "Adulto", "Joven")
print("Edades clasificadas: ", edades_cladificadas)

# Otro ejemplo pero sustituyendo los valores que coincidan con una condición
array_5d = np.random.randint(1, 101, size=(1, 2, 3, 4, 5))
print("Arrat 5D: ", array_5d)
array_5d[array_5d < 50] = 50
print("Array 5D reemplazado: ", array_5d)
# Out:
# Index del valor mas pequeño:  0
# Index del valor mas grande:  12
# Valores filtrados con indexación:  [65 44 55 64 89]
# Index de los valores filtrados:  (array([ 4,  8,  9, 10, 12]),)
# Valores edades:  [51 14 71 60 20 74 74 23  2 21]
# Edades clasificadas:  ['Adulto' 'Joven' 'Adulto' 'Adulto' 'Joven' 'Adulto' 'Adulto' 'Joven'
#  'Joven' 'Joven']
# Arrat 5D:  [[[[[ 53   2  88  30  38]
#     [  2  64  60  21  33]
#     [ 76  58  22  89  49]
#     [ 91  59  42  92  60]]
#
#    [[ 80  15  62  62  47]
#     [ 62  51  55  64   3]
#     [ 51   7  21  73  39]
#     [ 18   4  89  60  14]]
#
#    [[  9  90  53   2  84]
#     [ 92  60  71  44   8]
#     [ 47  35  78  81  36]
#     [ 50   4   2   6  54]]]
#
#
#   [[[  4  54  93  63  18]
#     [ 90  44  34  74  62]
#     [100  14  95  48  15]
#     [ 72  78  87  62  40]]
#
#    [[ 85  80  82  53  24]
#     [ 26  89  60  41  29]
#     [ 15  45  65  89  71]
#     [  9  88   1   8  88]]
#
#    [[ 63  11  81   8  35]
#     [ 35  33   5  41  28]
#     [  7  73  72  12  34]
#     [ 33  48  23  62  88]]]]]
# Array 5D reemplazado:  [[[[[ 53  50  88  50  50]
#     [ 50  64  60  50  50]
#     [ 76  58  50  89  50]
#     [ 91  59  50  92  60]]
#
#    [[ 80  50  62  62  50]
#     [ 62  51  55  64  50]
#     [ 51  50  50  73  50]
#     [ 50  50  89  60  50]]
#
#    [[ 50  90  53  50  84]
#     [ 92  60  71  50  50]
#     [ 50  50  78  81  50]
#     [ 50  50  50  50  54]]]
#
#
#   [[[ 50  54  93  63  50]
#     [ 90  50  50  74  62]
#     [100  50  95  50  50]
#     [ 72  78  87  62  50]]
#
#    [[ 85  80  82  53  50]
#     [ 50  89  60  50  50]
#     [ 50  50  65  89  71]
#     [ 50  88  50  50  88]]
#
#    [[ 63  50  81  50  50]
#     [ 50  50  50  50  50]
#     [ 50  73  72  50  50]
#     [ 50  50  50  62  88]]]]]

# %% [markdown]
# # Leer datos CSV
# Mediante Numpy

# %%
from tabulate import tabulate

data = np.genfromtxt(
    "Catalog_v2.csv", delimiter=",", skip_header=1, filling_values=0, dtype=str
)

column_1 = data[:, 0]
column_2 = data[:, 1]
column_3 = data[:, 2]
fila_6 = data[4, :]

"""
print("Columna 1: ", column_1)
print("Columna 2: ", column_2)
print("Columna 3: ", column_3)"""
print("Fila 6: ", fila_6)

print(tabulate(data, headers="keys", tablefmt="psql"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 from tabulate import tabulate
# ----> 3 data = np.genfromtxt(
#       4     "Catalog_v2.csv", delimiter=",", skip_header=1, filling_values=0, dtype=str
#       5 )
#       7 column_1 = data[:, 0]
#       8 column_2 = data[:, 1]
#
# File c:\Users\SergioSF\Desktop\Repositorios Github\.venv\lib\site-packages\numpy\lib\_npyio_impl.py:1990, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1988     fname = os.fspath(fname)
#    1989 if isinstance(fname, str):
# -> 1990     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1991     fid_ctx = contextlib.closing(fid)
#    1992 else:
#
# File c:\Users\SergioSF\Desktop\Repositorios Github\.venv\lib\site-packages\numpy\lib\_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)
#     188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File c:\Users\SergioSF\Desktop\Repositorios Github\.venv\lib\site-packages\numpy\lib\_datasource.py:529, in DataSource.open(self, path, mode, encoding, newline)
#     526     return _file_openers[ext](found, mode=mode,
#     527                               encoding=encoding, newline=newline)
#     528 else:
# --> 529     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: Catalog_v2.csv not found.

# %% [markdown]
# Mediante Pandas

# %%
import pandas as pd

# Leemos el csv y lo cargamos en un dataframe
df = pd.read_csv("Product_v6.csv")

# Mediante head() imprimimos las primeras 5 filas
print("5 primeras filas: ", df.head())

print(tabulate(df, headers="keys", tablefmt="psql"))

df.columns = df.columns.str.strip()
print("Todas las columnas: ", df.columns)

# accedemos a la columna de nombre 'value' mediante indexación
print("Columna code: ", df["value"])

# Slicing en dataframe mediante la funcion iloc[]
print("Fila 2: ", df.iloc[1, :])
print("Columa 5: ", df.iloc[:, 4])

# Cambiar las variables de configuración de pandas para imprimir el dataframe entero
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)


print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 import pandas as pd
#       3 # Leemos el csv y lo cargamos en un dataframe
# ----> 4 df = pd.read_csv("Product_v6.csv")
#       6 # Mediante head() imprimimos las primeras 5 filas
#       7 print("5 primeras filas: ", df.head())
#
# File c:\Users\SergioSF\Desktop\Repositorios Github\.venv\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\SergioSF\Desktop\Repositorios Github\.venv\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\SergioSF\Desktop\Repositorios Github\.venv\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\SergioSF\Desktop\Repositorios Github\.venv\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\SergioSF\Desktop\Repositorios Github\.venv\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Product_v6.csv'

# %%
# Leemos el CSV y lo convertimos en un Dataframe
df = pd.read_csv("Product_v6.csv")

# Creamos un array de Numpy mediante la columna 'value'
array_values = np.array(df["value"])

# Reducimos la varianza de los datos aplicando la raiz cuadrado sobre ellos
sqrt_array_values = np.sqrt(array_values)

# Añadimos nuestro array como una nueva columna al dataframe
df["sqrt_values"] = sqrt_array_values

# Creamos un nuevo CSV con nuestro dataframe modificado
df.to_csv("datos_modificados.csv", index=False)

# Aplicamos un 10% a todos los valores de sqrt_values
df["raw_sqrt"] = df["sqrt_values"] * 0.9

# Realizamos un filtrado de datos mediante la funcion .loc[condicion, "nombre_columna"] (Multiplicamos por 2 los valores de Value mayores a 1000)
df.loc[df["value"] > 1000, "value"] *= 2

# Elevamos al cuadrado todos los valores de la columna raw_sqrt menores de 60 y mayores de 40
df.loc[(df["raw_sqrt"] < 60) & (df["raw_sqrt"] > 40), "raw_sqrt"] **= 2

# Mostramos el nuevo Dataframe
print(tabulate(df, headers="keys", tablefmt="psql"))
# Out:
# +----+--------------+---------------+-------------------------+---------------+------------------------------+---------------------+-----------------------+----------+---------+-----------------+------------------------+-----------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------+---------------+---------------------------------+---------------+------------+
# |    | partNumber   | productType   | category.code           | brand.code    | family.code                  | line.code           |   productSegment.code | status   |   value | valueCurrency   | defaultQuantityUnits   | name                                                                  | description                                                                                                | plannerCode   | sourceLink                      |   sqrt_values |   raw_sqrt |
# |----+--------------+---------------+-------------------------+---------------+------------------------------+---------------------+-----------------------+----------+---------+-----------------+------------------------+-----------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------+---------------+---------------------------------+---------------+------------|
# |  0 | PS-SL-A287   | PRODUCT       | Street Lighting         | Public Sector | Alliance                     | Rural               |                   nan | ACTIVE   |    2500 | USD             | EA                     | Alliance 150W HPS 25' Luminaire and Pole, Silver                      | Public Sector Street Lighting - Alliance 150W HPS 25' Luminaire and Pole, Silver                           | Lighting      | http://lighttree.com/PS-SL-A287 |      35.3553  |   31.8198  |
# |  1 | PS-SL-A288   | PRODUCT       | Street Lighting         | Public Sector | Alliance                     | Rural               |                   nan | ACTIVE   |    2500 | USD             | EA                     | Alliance 100W HPS 25' Luminaire and Pole, Silver                      | Public Sector Street Lighting - Alliance 100W HPS 25' Luminaire and Pole, Silver                           | Lighting      | http://lighttree.com/PS-SL-A288 |      35.3553  |   31.8198  |
# |  2 | PS-SL-H309   | PRODUCT       | Street Lighting         | Public Sector | Helm                         | Rural               |                   nan | ACTIVE   |    2500 | USD             | EA                     | Helm 150W HPS 30' Luminaire and Pole, Black                           | Public Sector Street Lighting - Helm 150W HPS 30' Luminaire and Pole, Black                                | Lighting      | http://lighttree.com/PS-SL-H309 |      35.3553  |   31.8198  |
# |  3 | PS-SL-H310   | PRODUCT       | Street Lighting         | Public Sector | Helm                         | Rural               |                   nan | ACTIVE   |    2500 | USD             | EA                     | Helm 100W HPS 30' Luminaire and Pole, Black                           | Public Sector Street Lighting - Helm 100W HPS 30' Luminaire and Pole, Black                                | Lighting      | http://lighttree.com/PS-SL-H310 |      35.3553  |   31.8198  |
# |  4 | PS-SL-F342   | PRODUCT       | Street Lighting         | Public Sector | Flatbush Avenue              | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Flatbush Avenue Twin 250W 30' Teardrop Lumi. and Pole, Black          | Public Sector Street Lighting - Flatbush Avenue Twin 250W 30' Teardrop Lumi. and Pole, Black               | Lighting      | http://lighttree.com/PS-SL-F342 |      35.3553  |   31.8198  |
# |  5 | PS-SL-F343   | PRODUCT       | Street Lighting         | Public Sector | Flatbush Avenue              | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Flatbush Avenue Single 250W 30' Teardrop Lumi. and Pole, Black        | Public Sector Street Lighting - Flatbush Avenue Single 250W 30' Teardrop Lumi. and Pole, Black             | Lighting      | http://lighttree.com/PS-SL-F343 |      35.3553  |   31.8198  |
# |  6 | PS-SL-F344   | PRODUCT       | Street Lighting         | Public Sector | Flatbush Avenue              | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Flatbush Avenue Twin 250W 30' Teardrop Lumi. and Pole, Brown          | Public Sector Street Lighting - Flatbush Avenue Twin 250W 30' Teardrop Lumi. and Pole, Brown               | Lighting      | http://lighttree.com/PS-SL-F344 |      35.3553  |   31.8198  |
# |  7 | PS-SL-F345   | PRODUCT       | Street Lighting         | Public Sector | Flatbush Avenue              | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Flatbush Avenue Single 250W 30' Teardrop Lumi. and Pole, Brown        | Public Sector Street Lighting - Flatbush Avenue Single 250W 30' Teardrop Lumi. and Pole, Brown             | Lighting      | http://lighttree.com/PS-SL-F345 |      35.3553  |   31.8198  |
# |  8 | PS-SL-B122   | PRODUCT       | Street Lighting         | Public Sector | Bishops Crook                | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Bishops Crook 250W HPS Historical teardrop Lumi. and pole             | Public Sector Street Lighting - Bishops Crook 250W HPS Historical teardrop Lumi. and pole                  | Lighting      | http://lighttree.com/PS-SL-B122 |      35.3553  |   31.8198  |
# |  9 | PS-SL-A123   | PRODUCT       | Street Lighting         | Public Sector | Bishops Crook                | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Bishops Crook IES Type III Historical teardrop Lumi. and pole         | Public Sector Street Lighting - Bishops Crook IES Type III Historical teardrop Lumi. and pole              | Lighting      | http://lighttree.com/PS-SL-A123 |      35.3553  |   31.8198  |
# | 10 | PS-SL-C280   | PRODUCT       | Street Lighting         | Public Sector | City Light                   | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | City Light 150W HPS 30' Luminaire and Pole, Black                     | Public Sector Street Lighting - City Light 150W HPS 30' Luminaire and Pole, Black                          | Lighting      | http://lighttree.com/PS-SL-C280 |      35.3553  |   31.8198  |
# | 11 | PS-SL-C193   | PRODUCT       | Street Lighting         | Public Sector | City Light                   | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | City Light 100W HPS 30' Luminaire and Pole, Black                     | Public Sector Street Lighting - City Light 100W HPS 30' Luminaire and Pole, Black                          | Lighting      | http://lighttree.com/PS-SL-C193 |      35.3553  |   31.8198  |
# | 12 | PS-SL-L327   | PRODUCT       | Street Lighting         | Public Sector | LED Type E                   | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | LED Type E Twin 250W 30' Teardrop Lumi. and Pole, Brown               | Public Sector Street Lighting - LED Type E Twin 250W 30' Teardrop Lumi. and Pole, Brown                    | Lighting      | http://lighttree.com/PS-SL-L327 |      35.3553  |   31.8198  |
# | 13 | PS-SL-L393   | PRODUCT       | Street Lighting         | Public Sector | LED Type E                   | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | LED Type E Single 250W 30' Teardrop Lumi. and Pole, Brown             | Public Sector Street Lighting - LED Type E Single 250W 30' Teardrop Lumi. and Pole, Brown                  | Lighting      | http://lighttree.com/PS-SL-L393 |      35.3553  |   31.8198  |
# | 14 | PS-SL-KIT    | PRODUCT       | Street Lighting         | Public Sector | All                          | City                |                   nan | ACTIVE   |       0 | USD             | EA                     | Public Sector Street Lighting Universal Installation Kit              | Public Sector Street Lighting - Public Sector Street Lighting Universal Installation Kit                   | Lighting      | http://lighttree.com/PS-SL-KIT  |       0       |    0       |
# | 15 | PS-SL-INFO   | PRODUCT       | Street Lighting         | Public Sector | All                          | City                |                   nan | INACTIVE |       0 | USD             | EA                     | Public Sector Street Lighting Universal Installation Instructions     | Public Sector Street Lighting - Public Sector Street Lighting Universal Installation Instructions          | Lighting      | http://lighttree.com/PS-SL-INFO |       0       |    0       |
# | 16 | PS-PL-C295   | PRODUCT       | Pedestrian Lighting     | Public Sector | Cobra Head                   | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Cobra Head 150W HPS 30' Luminaire and Pole, Black                     | Public Sector Pedestrian Lighting - Cobra Head 150W HPS 30' Luminaire and Pole, Black                      | Lighting      | http://lighttree.com/PS-PL-C295 |      35.3553  |   31.8198  |
# | 17 | PS-PL-C167   | PRODUCT       | Pedestrian Lighting     | Public Sector | Cobra Head                   | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Cobra Head 100W HPS 30' Luminaire and Pole, Black                     | Public Sector Pedestrian Lighting - Cobra Head 100W HPS 30' Luminaire and Pole, Black                      | Lighting      | http://lighttree.com/PS-PL-C167 |      35.3553  |   31.8198  |
# | 18 | PS-PL-S459   | PRODUCT       | Pedestrian Lighting     | Public Sector | Stad                         | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Stad Twin 250W 30' Teardrop Lumi. and Pole, Black                     | Public Sector Pedestrian Lighting - Stad Twin 250W 30' Teardrop Lumi. and Pole, Black                      | Lighting      | http://lighttree.com/PS-PL-S459 |      35.3553  |   31.8198  |
# | 19 | PS-PL-S236   | PRODUCT       | Pedestrian Lighting     | Public Sector | Stad                         | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Stad Single 250W 30' Teardrop Lumi. and Pole, Black                   | Public Sector Pedestrian Lighting - Stad Single 250W 30' Teardrop Lumi. and Pole, Black                    | Lighting      | http://lighttree.com/PS-PL-S236 |      35.3553  |   31.8198  |
# | 20 | PS-PL-F206   | PRODUCT       | Pedestrian Lighting     | Public Sector | Fulton                       | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Fulton Twin 250W 30' Teardrop Lumi. and Pole, Black                   | Public Sector Pedestrian Lighting - Fulton Twin 250W 30' Teardrop Lumi. and Pole, Black                    | Lighting      | http://lighttree.com/PS-PL-F206 |      35.3553  |   31.8198  |
# | 21 | PS-PL-F158   | PRODUCT       | Pedestrian Lighting     | Public Sector | Fulton                       | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Fulton Single 250W 30' Teardrop Lumi. and Pole, Black                 | Public Sector Pedestrian Lighting - Fulton Single 250W 30' Teardrop Lumi. and Pole, Black                  | Lighting      | http://lighttree.com/PS-PL-F158 |      35.3553  |   31.8198  |
# | 22 | PS-PL-F242   | PRODUCT       | Pedestrian Lighting     | Public Sector | Flushing Meadows             | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Flushing Meadows 150W HPS 25' Luminaire and Pole, Silver              | Public Sector Pedestrian Lighting - Flushing Meadows 150W HPS 25' Luminaire and Pole, Silver               | Lighting      | http://lighttree.com/PS-PL-F242 |      35.3553  |   31.8198  |
# | 23 | PS-PL-F388   | PRODUCT       | Pedestrian Lighting     | Public Sector | Flushing Meadows             | City                |                   nan | ACTIVE   |    2500 | USD             | EA                     | Flushing Meadows 100W HPS 25' Luminaire and Pole, Silver              | Public Sector Pedestrian Lighting - Flushing Meadows 100W HPS 25' Luminaire and Pole, Silver               | Lighting      | http://lighttree.com/PS-PL-F388 |      35.3553  |   31.8198  |
# | 24 | PS-PL-W140   | PRODUCT       | Pedestrian Lighting     | Public Sector | World's Fair                 | Special application |                   nan | ACTIVE   |    2500 | USD             | EA                     | World's Fair 150W HPS 30' Luminaire and Pole, Black                   | Public Sector Pedestrian Lighting - World's Fair 150W HPS 30' Luminaire and Pole, Black                    | Lighting      | http://lighttree.com/PS-PL-W140 |      35.3553  |   31.8198  |
# | 25 | PS-PL-W381   | PRODUCT       | Pedestrian Lighting     | Public Sector | World's Fair                 | Special application |                   nan | ACTIVE   |    2500 | USD             | EA                     | World's Fair 100W HPS 30' Luminaire and Pole, Black                   | Public Sector Pedestrian Lighting - World's Fair 100W HPS 30' Luminaire and Pole, Black                    | Lighting      | http://lighttree.com/PS-PL-W381 |      35.3553  |   31.8198  |
# | 26 | PS-PL-R186   | PRODUCT       | Pedestrian Lighting     | Public Sector | Round Top Head               | Special application |                   nan | ACTIVE   |    2500 | USD             | EA                     | Round Top Head IES Type III Historical teardrop Lumi. and pole        | Public Sector Pedestrian Lighting - Round Top Head IES Type III Historical teardrop Lumi. and pole         | Lighting      | http://lighttree.com/PS-PL-R186 |      35.3553  |   31.8198  |
# | 27 | PS-PL-KIT    | PRODUCT       | Pedestrian Lighting     | Public Sector | All                          | Special application |                   nan | ACTIVE   |       0 | USD             | EA                     | Public Sector Pedestrian Lighting Universal Installation Kit          | Public Sector Pedestrian Lighting - Public Sector Pedestrian Lighting Universal Installation Kit           | Lighting      | http://lighttree.com/PS-PL-KIT  |       0       |    0       |
# | 28 | PS-PL-INFO   | PRODUCT       | Pedestrian Lighting     | Public Sector | All                          | Special application |                   nan | ACTIVE   |       0 | USD             | EA                     | Public Sector Pedestrian Lighting Universal Installation Instructions | Public Sector Pedestrian Lighting - Public Sector Pedestrian Lighting Universal Installation Instructions  | Lighting      | http://lighttree.com/PS-PL-INFO |       0       |    0       |
# | 29 | PS-TS-T264   | PRODUCT       | Traffic Signal Poles    | Public Sector | Type M-2 Traffic Signal Pole | Traffic             |                   nan | ACTIVE   |    2900 | USD             | EA                     | Type M-2 Traffic Signal Pole                                          | Public Sector Traffic Signal Poles - Type M-2 Traffic Signal Pole                                          | Poles         | http://lighttree.com/PS-TS-T264 |      38.0789  |   34.271   |
# | 30 | PS-TS-A318   | PRODUCT       | Traffic Signal Poles    | Public Sector | Alliance Traffic Signal Pole | Traffic             |                   nan | ACTIVE   |    2900 | USD             | EA                     | Alliance Traffic Signal Pole                                          | Public Sector Traffic Signal Poles - Alliance Traffic Signal Pole                                          | Poles         | http://lighttree.com/PS-TS-A318 |      38.0789  |   34.271   |
# | 31 | PS-TS-KIT    | PRODUCT       | Traffic Signal Poles    | Public Sector | All                          | Traffic             |                   nan | ACTIVE   |       0 | USD             | EA                     | Public Sector Traffic Signal Pole Universal Installation Kit          | Public Sector Traffic Signal Poles - Public Sector Traffic Signal Pole Universal Installation Kit          | Poles         | http://lighttree.com/PS-TS-KIT  |       0       |    0       |
# | 32 | PS-TS-INFO   | PRODUCT       | Traffic Signal Poles    | Public Sector | All                          | Traffic             |                   nan | INACTIVE |       0 | USD             | EA                     | Public Sector Traffic Signal Pole Universal Installation Instructions | Public Sector Traffic Signal Poles - Public Sector Traffic Signal Pole Universal Installation Instructions | Poles         | http://lighttree.com/PS-TS-INFO |       0       |    0       |
# | 33 | CO-CO-V310   | PRODUCT       | Controls                | Commercial    | Ventura                      | nan                 |                   nan | ACTIVE   |     100 | USD             | EA                     | Ventura 48VDC control module                                          | Commercial Controls - Ventura 48VDC control module                                                         | Electrical    | http://lighttree.com/CO-CO-V310 |      10       |    9       |
# | 34 | CO-CO-N311   | PRODUCT       | Controls                | Commercial    | Northridge                   | nan                 |                   nan | ACTIVE   |     250 | USD             | EA                     | Northridge  230VAC control module                                     | Commercial Controls - Northridge  230VAC control module                                                    | Electrical    | http://lighttree.com/CO-CO-N311 |      15.8114  |   14.2302  |
# | 35 | CO-CO-M328   | PRODUCT       | Controls                | Commercial    | Miramar                      | nan                 |                   nan | ACTIVE   |     125 | USD             | EA                     | Miramar  110VAC control module                                        | Commercial Controls - Miramar  110VAC control module                                                       | Electrical    | http://lighttree.com/CO-CO-M328 |      11.1803  |   10.0623  |
# | 36 | CO-DL-T316   | PRODUCT       | Downlights              | Commercial    | Tulare                       | nan                 |                   nan | ACTIVE   |      55 | USD             | EA                     | Tulare 6 inch recessed downlight                                      | Commercial Downlights - Tulare 6 inch recessed downlight                                                   | Lighting      | http://lighttree.com/CO-DL-T316 |       7.4162  |    6.67458 |
# | 37 | CO-DL-A239   | PRODUCT       | Downlights              | Commercial    | Alameda                      | nan                 |                   nan | ACTIVE   |      48 | USD             | EA                     | Alameda 5 inch recessed downlight                                     | Commercial Downlights - Alameda 5 inch recessed downlight                                                  | Lighting      | http://lighttree.com/CO-DL-A239 |       6.9282  |    6.23538 |
# | 38 | CO-DL-A230   | PRODUCT       | Downlights              | Commercial    | Alpine                       | nan                 |                   nan | ACTIVE   |      51 | USD             | EA                     | Alpine Water resistant 6 inch downlight                               | Commercial Downlights - Alpine Water resistant 6 inch downlight                                            | Lighting      | http://lighttree.com/CO-DL-A230 |       7.14143 |    6.42729 |
# | 39 | CO-RD-I380   | PRODUCT       | Retrofit Downlights     | Commercial    | Imperial                     | nan                 |                   nan | ACTIVE   |      78 | USD             | EA                     | Imperial  6 inch recessed downlight                                   | Commercial Retrofit Downlights - Imperial  6 inch recessed downlight                                       | Lighting      | http://lighttree.com/CO-RD-I380 |       8.83176 |    7.94858 |
# | 40 | CO-RD-S282   | PRODUCT       | Retrofit Downlights     | Commercial    | Sunset                       | nan                 |                   nan | ACTIVE   |      88 | USD             | EA                     | Sunset  5 inch recessed downlight                                     | Commercial Retrofit Downlights - Sunset  5 inch recessed downlight                                         | Lighting      | http://lighttree.com/CO-RD-S282 |       9.38083 |    8.44275 |
# | 41 | CO-RD-R296   | PRODUCT       | Retrofit Downlights     | Commercial    | Riverside                    | nan                 |                   nan | ACTIVE   |      93 | USD             | EA                     | Riverside Water resistant 6 inch downlight                            | Commercial Retrofit Downlights - Riverside Water resistant 6 inch downlight                                | Lighting      | http://lighttree.com/CO-RD-R296 |       9.64365 |    8.67929 |
# | 42 | CO-AM-B209   | PRODUCT       | Ambient                 | Commercial    | Buccaneer                    | nan                 |                   nan | ACTIVE   |     120 | USD             | EA                     | Buccaneer Wall mount luminous panel                                   | Commercial Ambient - Buccaneer Wall mount luminous panel                                                   | Lighting      | http://lighttree.com/CO-AM-B209 |      10.9545  |    9.85901 |
# | 43 | CO-AM-S185   | PRODUCT       | Ambient                 | Commercial    | Santa Cruz                   | nan                 |                   nan | ACTIVE   |     289 | USD             | EA                     | Santa Cruz 15W overhead lighting                                      | Commercial Ambient - Santa Cruz 15W overhead lighting                                                      | Lighting      | http://lighttree.com/CO-AM-S185 |      17       |   15.3     |
# | 44 | CO-AM-S393   | PRODUCT       | Ambient                 | Commercial    | Stinson                      | nan                 |                   nan | ACTIVE   |     183 | USD             | EA                     | Stinson Exterior daylight sensing area LED                            | Commercial Ambient - Stinson Exterior daylight sensing area LED                                            | Lighting      | http://lighttree.com/CO-AM-S393 |      13.5277  |   12.175   |
# | 45 | 29000462     | ITEM          | Bulbs                   | nan           | nan                          | nan                 |                   nan | ACTIVE   |      95 | USD             | EA                     | NaHP-TC Sodium Bulb 480V                                              | Bulbs - NaHP-TC Sodium Bulb 480V                                                                           | Lighting      | http://lighttree.com/29000462   |       9.74679 |    8.77211 |
# | 46 | 29000469     | ITEM          | Bulbs                   | nan           | nan                          | nan                 |                   nan | ACTIVE   |     108 | USD             | EA                     | NaHP-TC Sodium Bulb 600v                                              | Bulbs - NaHP-TC Sodium Bulb 600v                                                                           | Lighting      | http://lighttree.com/29000469   |      10.3923  |    9.35307 |
# | 47 | 7900128      | ITEM          | Controllers             | nan           | nan                          | nan                 |                   nan | INACTIVE |     320 | USD             | EA                     | Lighting Controller, Base Mounted, 480volt, 200amp                    | Controllers - Lighting Controller, Base Mounted, 480volt, 200amp                                           | Electrical    | http://lighttree.com/7900128    |      17.8885  |   16.0997  |
# | 48 | 82500380     | ITEM          | Controllers             | nan           | nan                          | nan                 |                   nan | ACTIVE   |     350 | USD             | EA                     | Lighting Controller, Base Mounted, 600volt, 200amp                    | Controllers - Lighting Controller, Base Mounted, 600volt, 200amp                                           | Electrical    | http://lighttree.com/82500380   |      18.7083  |   16.8375  |
# | 49 | 7900063      | ITEM          | Enclosures              | nan           | nan                          | nan                 |                   nan | ACTIVE   |      50 | USD             | EA                     | Junction Box 8" X 24" X 10"                                           | Enclosures - Junction Box 8" X 24" X 10"                                                                   | Electrical    | http://lighttree.com/7900063    |       7.07107 |    6.36396 |
# | 50 | 2510188      | ITEM          | High Voltage Electrical | nan           | nan                          | nan                 |                   nan | ACTIVE   |     412 | USD             | EA                     | U/G Supply To Pole-Mounted Luminaire                                  | High Voltage Electrical - U/G Supply To Pole-Mounted Luminaire                                             | Electrical    | http://lighttree.com/2510188    |      20.2978  |   18.268   |
# | 51 | 9665304      | ITEM          | High Voltage Electrical | nan           | nan                          | nan                 |                   nan | ACTIVE   |     422 | USD             | EA                     | U/G Supply To Pole-Mounted Luminaire At The                           | High Voltage Electrical - U/G Supply To Pole-Mounted Luminaire At The                                      | Electrical    | http://lighttree.com/9665304    |      20.5426  |   18.4884  |
# | 52 | 23000362     | ITEM          | High Voltage Electrical | nan           | nan                          | nan                 |                   nan | INACTIVE |     455 | USD             | EA                     | Electric Cable In Conduit, 600v                                       | High Voltage Electrical - Electric Cable In Conduit, 600v                                                  | Electrical    | http://lighttree.com/23000362   |      21.3307  |   19.1977  |
# | 53 | 81028220     | ITEM          | High Voltage Electrical | nan           | nan                          | nan                 |                   nan | ACTIVE   |     122 | USD             | EA                     | Underground Conduit, Galvanized Steel, 3" Dia.                        | High Voltage Electrical - Underground Conduit, Galvanized Steel, 3" Dia.                                   | Electrical    | http://lighttree.com/81028220   |      11.0454  |    9.94082 |
# | 54 | 81603000     | ITEM          | High Voltage Electrical | nan           | nan                          | nan                 |                   nan | ACTIVE   |      55 | USD             | EA                     | Unit Duct, 600v, 2-1c No. 8, 1/C No. 8 Ground, (Xlp-Type Use),        | High Voltage Electrical - Unit Duct, 600v, 2-1c No. 8, 1/C No. 8 Ground, (Xlp-Type Use),                   | Electrical    | http://lighttree.com/81603000   |       7.4162  |    6.67458 |
# | 55 | 81603030     | ITEM          | High Voltage Electrical | nan           | nan                          | nan                 |                   nan | ACTIVE   |      55 | USD             | EA                     | Unit Duct, 600v, 2-1c No. 4, 1/C No. 6 Ground, (Xlp-Type Use),        | High Voltage Electrical - Unit Duct, 600v, 2-1c No. 4, 1/C No. 6 Ground, (Xlp-Type Use),                   | Electrical    | http://lighttree.com/81603030   |       7.4162  |    6.67458 |
# | 56 | 86000121     | ITEM          | High Voltage Electrical | nan           | nan                          | nan                 |                   nan | ACTIVE   |      55 | USD             | EA                     | Unit Duct, 600v, 4-1c No.6, 1/C No.6 Ground                           | High Voltage Electrical - Unit Duct, 600v, 4-1c No.6, 1/C No.6 Ground                                      | Electrical    | http://lighttree.com/86000121   |       7.4162  |    6.67458 |
# | 57 | 86000123     | ITEM          | High Voltage Electrical | nan           | nan                          | nan                 |                   nan | ACTIVE   |      55 | USD             | EA                     | Unit Duct, 600v, 2-1c No.4, 1/C No.6 Ground                           | High Voltage Electrical - Unit Duct, 600v, 2-1c No.4, 1/C No.6 Ground                                      | Electrical    | http://lighttree.com/86000123   |       7.4162  |    6.67458 |
# | 58 | 86000124     | ITEM          | High Voltage Electrical | nan           | nan                          | nan                 |                   nan | ACTIVE   |      55 | USD             | EA                     | Unit Duct, 600v, 2-1c No.2, 1/C No.4 Ground                           | High Voltage Electrical - Unit Duct, 600v, 2-1c No.2, 1/C No.4 Ground                                      | Electrical    | http://lighttree.com/86000124   |       7.4162  |    6.67458 |
# | 59 | 39000221     | ITEM          | Lenses                  | nan           | nan                          | nan                 |                   nan | ACTIVE   |     190 | USD             | EA                     | 230 cm Acrylic Street Lamp Lens                                       | Lenses - 230 cm Acrylic Street Lamp Lens                                                                   | Lighting      | http://lighttree.com/39000221   |      13.784   |   12.4056  |
# | 60 | 39000224     | ITEM          | Lenses                  | nan           | nan                          | nan                 |                   nan | ACTIVE   |     203 | USD             | EA                     | 340 cm Acrylic Street Lamp Lens                                       | Lenses - 340 cm Acrylic Street Lamp Lens                                                                   | Lighting      | http://lighttree.com/39000224   |      14.2478  |   12.823   |
# | 61 | 2000287      | ITEM          | Luminaire               | nan           | nan                          | nan                 |                   nan | ACTIVE   |     112 | USD             | EA                     | Luminaire, Metal Halide, Horizontal Mount, 70 Watt, Special           | Luminaire - Luminaire, Metal Halide, Horizontal Mount, 70 Watt, Special                                    | Lighting      | http://lighttree.com/2000287    |      10.583   |    9.5247  |
# | 62 | 8210677      | ITEM          | Luminaire               | nan           | nan                          | nan                 |                   nan | ACTIVE   |     189 | USD             | EA                     | Luminaire, Metal Halide, Horizontal Mount, 400 Watt, Special          | Luminaire - Luminaire, Metal Halide, Horizontal Mount, 400 Watt, Special                                   | Lighting      | http://lighttree.com/8210677    |      13.7477  |   12.373   |
# | 63 | 9665303      | ITEM          | Luminaire               | nan           | nan                          | nan                 |                   nan | ACTIVE   |     950 | USD             | EA                     | Cobra Head Luminaire                                                  | Luminaire - Cobra Head Luminaire                                                                           | Lighting      | http://lighttree.com/9665303    |      30.8221  |   27.7399  |
# | 64 | 45000222     | ITEM          | Luminaire               | nan           | nan                          | nan                 |                   nan | ACTIVE   |     774 | USD             | EA                     | Luminaire, Sodium Vapor, Horizontal Mount, 400 Watt                   | Luminaire - Luminaire, Sodium Vapor, Horizontal Mount, 400 Watt                                            | Lighting      | http://lighttree.com/45000222   |      27.8209  |   25.0388  |
# | 65 | 45000223     | ITEM          | Luminaire               | nan           | nan                          | nan                 |                   nan | ACTIVE   |     774 | USD             | EA                     | Luminaire, Sodium Vapor, Horizontal Mount, 600 Watt                   | Luminaire - Luminaire, Sodium Vapor, Horizontal Mount, 600 Watt                                            | Lighting      | http://lighttree.com/45000223   |      27.8209  |   25.0388  |
# | 66 | 45000225     | ITEM          | Luminaire               | nan           | nan                          | nan                 |                   nan | INACTIVE |     774 | USD             | EA                     | Luminaire, Sodium Vapor, Horizontal Mount, 800 Watt                   | Luminaire - Luminaire, Sodium Vapor, Horizontal Mount, 800 Watt                                            | Lighting      | http://lighttree.com/45000225   |      27.8209  |   25.0388  |
# | 67 | 45000226     | ITEM          | Luminaire               | nan           | nan                          | nan                 |                   nan | ACTIVE   |     774 | USD             | EA                     | Luminaire, Sodium Vapor, Horizontal Mount, 1000 Watt                  | Luminaire - Luminaire, Sodium Vapor, Horizontal Mount, 1000 Watt                                           | Lighting      | http://lighttree.com/45000226   |      27.8209  |   25.0388  |
# | 68 | 7900012      | ITEM          | Mechanicals             | nan           | nan                          | nan                 |                   nan | ACTIVE   |       5 | USD             | EA                     | Bolt Machine 5/8" X 10"- 11 Unc Square Head And Nut                   | Mechanicals - Bolt Machine 5/8" X 10"- 11 Unc Square Head And Nut                                          | Mechanicals   | http://lighttree.com/7900012    |       2.23607 |    2.01246 |
# | 69 | 7900014      | ITEM          | Mechanicals             | nan           | nan                          | nan                 |                   nan | ACTIVE   |      19 | USD             | EA                     | Buckle 3/4" Banding Steel                                             | Mechanicals - Buckle 3/4" Banding Steel                                                                    | Mechanicals   | http://lighttree.com/7900014    |       4.3589  |    3.92301 |
# | 70 | 7900015      | ITEM          | Mechanicals             | nan           | nan                          | nan                 |                   nan | ACTIVE   |       3 | USD             | EA                     | Washer Curved Square Galv 2" X 2" For 4" Bolt                         | Mechanicals - Washer Curved Square Galv 2" X 2" For 4" Bolt                                                | Mechanicals   | http://lighttree.com/7900015    |       1.73205 |    1.55885 |
# | 71 | 9664144      | ITEM          | Mechanicals             | nan           | nan                          | nan                 |                   nan | ACTIVE   |      24 | USD             | EA                     | Banding Stainless Steel 0.030" X 100' Roll                            | Mechanicals - Banding Stainless Steel 0.030" X 100' Roll                                                   | Mechanicals   | http://lighttree.com/9664144    |       4.89898 |    4.40908 |
# | 72 | 9665306      | ITEM          | Mechanicals             | nan           | nan                          | nan                 |                   nan | ACTIVE   |       3 | USD             | EA                     | Washer Galv Square 2" X 2" For 3" Bolt                                | Mechanicals - Washer Galv Square 2" X 2" For 3" Bolt                                                       | Mechanicals   | http://lighttree.com/9665306    |       1.73205 |    1.55885 |
# | 73 | 2530003      | ITEM          | Primary Chassis         | nan           | nan                          | nan                 |                   nan | ACTIVE   |    2580 | USD             | EA                     | Pole Concrete 35' Round Class C Direct Buried                         | Primary Chassis - Pole Concrete 35' Round Class C Direct Buried                                            | Mechanicals   | http://lighttree.com/2530003    |      35.9166  |   32.3249  |
# | 74 | 2530020      | ITEM          | Primary Chassis         | nan           | nan                          | nan                 |                   nan | ACTIVE   |    2360 | USD             | EA                     | Pole Concrete 30' Round Class C Direct Buried                         | Primary Chassis - Pole Concrete 30' Round Class C Direct Buried                                            | Mechanicals   | http://lighttree.com/2530020    |      34.3511  |   30.916   |
# | 75 | 7903986      | ITEM          | Primary Chassis         | nan           | nan                          | nan                 |                   nan | ACTIVE   |     990 | USD             | EA                     | Pole Concrete 25' Round Class C Base Mounted                          | Primary Chassis - Pole Concrete 25' Round Class C Base Mounted                                             | Mechanicals   | http://lighttree.com/7903986    |      31.4643  |   28.3178  |
# | 76 | 8220072      | ITEM          | Primary Chassis         | nan           | nan                          | nan                 |                   nan | ACTIVE   |    2904 | USD             | EA                     | Pole Concrete 40' Round Class C Direct Buried                         | Primary Chassis - Pole Concrete 40' Round Class C Direct Buried                                            | Mechanicals   | http://lighttree.com/8220072    |      38.1051  |   34.2946  |
# | 77 | 83008200     | ITEM          | Primary Chassis         | nan           | nan                          | nan                 |                   nan | ACTIVE   |    4796 | USD             | EA                     | Light Pole, Aluminum, 40 Ft. M.H., 6 Ft. Mast Arm Each 17             | Primary Chassis - Light Pole, Aluminum, 40 Ft. M.H., 6 Ft. Mast Arm Each 17                                | Mechanicals   | http://lighttree.com/83008200   |      48.9694  | 1942.38    |
# | 78 | 83008300     | ITEM          | Primary Chassis         | nan           | nan                          | nan                 |                   nan | ACTIVE   |    9184 | USD             | EA                     | Light Pole, Aluminum, 40 Ft. M.H., 8 Ft. Mast Arm Each 7              | Primary Chassis - Light Pole, Aluminum, 40 Ft. M.H., 8 Ft. Mast Arm Each 7                                 | Mechanicals   | http://lighttree.com/83008300   |      67.7643  |   60.9879  |
# | 79 | 83008400     | ITEM          | Primary Chassis         | nan           | nan                          | nan                 |                   nan | ACTIVE   |   11060 | USD             | EA                     | Light Pole, Aluminum, 40 Ft. M.H., 10 Ft. Mast Arm Each 37            | Primary Chassis - Light Pole, Aluminum, 40 Ft. M.H., 10 Ft. Mast Arm Each 37                               | Mechanicals   | http://lighttree.com/83008400   |      74.364   |   66.9276  |
# | 80 | 89820200     | ITEM          | Primary Chassis         | nan           | nan                          | nan                 |                   nan | ACTIVE   |    4698 | USD             | EA                     | Light Pole, Galvanized Steel, 50 Ft. M.H., 12 Ft. Mast Arm, Twin      | Primary Chassis - Light Pole, Galvanized Steel, 50 Ft. M.H., 12 Ft. Mast Arm, Twin                         | Mechanicals   | http://lighttree.com/89820200   |      48.4665  | 1902.69    |
# | 81 | 83600200     | ITEM          | Primary Foundation      | nan           | nan                          | nan                 |                   nan | ACTIVE   |    2574 | USD             | EA                     | Light Pole Foundation, 24" Diameter                                   | Primary Foundation - Light Pole Foundation, 24" Diameter                                                   | Mechanicals   | http://lighttree.com/83600200   |      35.8748  |   32.2873  |
# | 82 | 83600300     | ITEM          | Primary Foundation      | nan           | nan                          | nan                 |                   nan | INACTIVE |    2912 | USD             | EA                     | Light Pole Foundation, 30" Diameter                                   | Primary Foundation - Light Pole Foundation, 30" Diameter                                                   | Mechanicals   | http://lighttree.com/83600300   |      38.1576  |   34.3418  |
# | 83 | 9664145      | ITEM          | Secondary Chassis       | nan           | nan                          | nan                 |                   nan | ACTIVE   |     833 | USD             | EA                     | Bracket Al Tapered 6' Reach                                           | Secondary Chassis - Bracket Al Tapered 6' Reach                                                            | Mechanicals   | http://lighttree.com/9664145    |      28.8617  |   25.9756  |
# | 84 | 9664146      | ITEM          | Secondary Chassis       | nan           | nan                          | nan                 |                   nan | ACTIVE   |    2064 | USD             | EA                     | Bracket Al Tapered 8' Reach                                           | Secondary Chassis - Bracket Al Tapered 8' Reach                                                            | Mechanicals   | http://lighttree.com/9664146    |      32.1248  |   28.9123  |
# | 85 | 9664147      | ITEM          | Secondary Chassis       | nan           | nan                          | nan                 |                   nan | ACTIVE   |     976 | USD             | EA                     | Bracket Al Tapered 7' Rise                                            | Secondary Chassis - Bracket Al Tapered 7' Rise                                                             | Mechanicals   | http://lighttree.com/9664147    |      31.241   |   28.1169  |
# +----+--------------+---------------+-------------------------+---------------+------------------------------+---------------------+-----------------------+----------+---------+-----------------+------------------------+-----------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------+---------------+---------------------------------+---------------+------------+

# %% [markdown]
# # ESTADÍSTICA

# %%
# Creamos un data frame con valores aleatorios
df = pd.DataFrame({
    "id": range(1, 11), 
    "ventas": np.random.randint(100, 1000, size=10)
    })

# MEDIA: Valor promedio de un conjunto de valores
df['media_ventas'] = df["ventas"].mean()

# MEDIANA: Valor central en una serie de datos ordenados ascendentemente
df["mediana_ventas"] = df["ventas"].median()

# DESVIACIÓN ESTÁNDAR: Calcula la dispersión de los datos respecto a la media.
df["desviacion_ventas"] = df["ventas"].std()

# NORMALIZACIÓN: Mediante la media y la desviación estándar
df["ventas_normalizadas"] = (df["ventas"] - df["ventas"].mean()) / df["ventas"].std() # Se aplica la fórmula de normalización Z-score: (X - media) / desviación estándar
# Mediante esta operación definimos los datos en una escala donde la media es 0 y la desviación estándar es 1

# Miniejercicio: Crea una nueva columna que contenga la media  y otra columna con la desviación estándar de ventas_normalizadas
df["media_ventas_normalizadas"] = df["ventas_normalizadas"].mean()
df["desviacion_ventas_normalizadas"] = df["ventas_normalizadas"].std()

print(tabulate(df, headers="keys", tablefmt="psql"))
# Out:
# +----+------+----------+----------------+------------------+---------------------+-----------------------+-----------------------------+----------------------------------+
# |    |   id |   ventas |   media_ventas |   mediana_ventas |   desviacion_ventas |   ventas_normalizadas |   media_ventas_normalizadas |   desviacion_ventas_normalizadas |
# |----+------+----------+----------------+------------------+---------------------+-----------------------+-----------------------------+----------------------------------|
# |  0 |    1 |      904 |            718 |            762.5 |              218.46 |             0.851413  |                -9.71445e-18 |                                1 |
# |  1 |    2 |      198 |            718 |            762.5 |              218.46 |            -2.3803    |                -9.71445e-18 |                                1 |
# |  2 |    3 |      783 |            718 |            762.5 |              218.46 |             0.297537  |                -9.71445e-18 |                                1 |
# |  3 |    4 |      971 |            718 |            762.5 |              218.46 |             1.15811   |                -9.71445e-18 |                                1 |
# |  4 |    5 |      825 |            718 |            762.5 |              218.46 |             0.489792  |                -9.71445e-18 |                                1 |
# |  5 |    6 |      646 |            718 |            762.5 |              218.46 |            -0.329579  |                -9.71445e-18 |                                1 |
# |  6 |    7 |      838 |            718 |            762.5 |              218.46 |             0.549299  |                -9.71445e-18 |                                1 |
# |  7 |    8 |      712 |            718 |            762.5 |              218.46 |            -0.0274649 |                -9.71445e-18 |                                1 |
# |  8 |    9 |      561 |            718 |            762.5 |              218.46 |            -0.718666  |                -9.71445e-18 |                                1 |
# |  9 |   10 |      742 |            718 |            762.5 |              218.46 |             0.10986   |                -9.71445e-18 |                                1 |
# +----+------+----------+----------------+------------------+---------------------+-----------------------+-----------------------------+----------------------------------+

# %%
import scipy.stats as stats

"""1- Leer el csv ShipmentLine_v3 y convertiro en DataFrame
2- Almacenar en un array los valores de la columna "order.orderIdentifier", y en otro array los valores de la columna "value"
3- Aplizar la normalización Z-Score a los ambas columnas.
4- Vamos a comprobar si realmente la desviación de los valores normalizados es 1
y si la media de los valores normalizados es 0 (o ronda el 0)"""
df = pd.read_csv("ShipmentLine_v3.csv")

order_ids_column = df["order.orderIdentifier"]
value_column = df["value"]

order_ids_column = stats.zscore(order_ids_column)
value_column = stats.zscore(value_column)

df_normalizado = pd.DataFrame({
    "Ids_normalizados" : order_ids_column,
    "Valores_normalizados" : value_column,
    "Media_ids_normalizados" : order_ids_column.mean(),
    "Media_valores_normalizados" : value_column.mean(),
    "Desviacion_ids_normalizados" : order_ids_column.std(),
    "Desviacion" : order_ids_column.std()
})
print(tabulate(df_normalizado, headers="keys", tablefmt="psql"))
# Out:
# +-----+--------------------+------------------------+--------------------------+------------------------------+-------------------------------+--------------+
# |     |   Ids_normalizados |   Valores_normalizados |   Media_ids_normalizados |   Media_valores_normalizados |   Desviacion_ids_normalizados |   Desviacion |
# |-----+--------------------+------------------------+--------------------------+------------------------------+-------------------------------+--------------|
# |   0 |          -2.13437  |             1.76715    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |   1 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |   2 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |   3 |          -2.13437  |             0.723454   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |   4 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |   5 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |   6 |          -2.13437  |            -0.00495882 |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |   7 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |   8 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |   9 |          -2.13437  |            -0.0375743  |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  10 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  11 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  12 |          -2.13437  |            -0.113677   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  13 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  14 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  15 |          -2.13437  |             3.09895    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  16 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  17 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  18 |          -2.13437  |            -0.0864976  |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  19 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  20 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  21 |          -2.13437  |            -0.287627   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  22 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  23 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  24 |          -2.13437  |             1.33228    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  25 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  26 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  27 |          -2.13437  |             1.33228    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  28 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  29 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  30 |          -2.13437  |            -0.206088   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  31 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  32 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  33 |          -2.13437  |             0.266837   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  34 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  35 |          -2.13437  |            -0.407217   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  36 |           0.468521 |            -0.403042   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  37 |           0.468521 |            -0.161861   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  38 |           0.468521 |             0.225959   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  39 |           0.468521 |            -0.396971   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  40 |           0.468521 |            -0.400259   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  41 |           0.468521 |             0.970463   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  42 |           0.468521 |            -0.185049   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  43 |           0.468521 |            -0.403042   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  44 |           0.468521 |            -0.330679   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  45 |           0.468521 |            -0.348979   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  46 |           0.468521 |            -0.124723   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  47 |           0.468521 |            -0.341429   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  48 |           0.468521 |            -0.405599   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  49 |           0.468521 |             0.105064   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  50 |           0.468521 |             7.28831    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  51 |           0.468521 |             2.06899    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  52 |           0.468521 |            -0.144205   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  53 |           0.468521 |             0.225959   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  54 |           0.468521 |            -0.337637   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  55 |           0.468521 |            -0.124723   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  56 |           0.468521 |             7.28831    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  57 |           0.468521 |             1.38377    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  58 |           0.468521 |            -0.405599   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  59 |           0.468521 |            -0.237442   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  60 |           0.468521 |            -0.337637   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  61 |           0.468521 |             0.95098    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  62 |           0.468521 |            -0.400537   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  63 |           0.468521 |            -0.380498   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  64 |           0.468521 |            -0.401237   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  65 |           0.468521 |            -0.383538   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  66 |           0.468521 |            -0.405599   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  67 |           0.468521 |            -0.396971   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  68 |           0.468521 |             0.119085   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  69 |           0.468521 |            -0.256925   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  70 |           0.468521 |            -0.237442   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  71 |           0.468521 |             1.38377    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  72 |           0.468521 |             0.180036   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  73 |           0.468521 |             0.375764   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  74 |           0.468521 |            -0.403042   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  75 |           0.468521 |             0.119085   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  76 |           0.468521 |             0.180036   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  77 |           0.468521 |            -0.380777   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  78 |           0.468521 |            -0.358511   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  79 |           0.468521 |             0.0311357  |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  80 |           0.468521 |            -0.404521   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  81 |           0.468521 |            -0.405599   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  82 |           0.468521 |            -0.394275   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  83 |           0.468521 |            -0.341429   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  84 |           0.468521 |            -0.179656   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  85 |           0.468521 |             0.16612    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  86 |           0.468521 |            -0.403042   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  87 |           0.468521 |            -0.144205   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  88 |           0.468521 |            -0.400259   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  89 |           0.468521 |            -0.394275   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  90 |           0.468521 |            -0.29775    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  91 |           0.468521 |            -0.312849   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  92 |           0.468521 |            -0.312849   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  93 |           0.468521 |             0.286789   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  94 |           0.468521 |            -0.256925   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  95 |           0.468521 |            -0.404521   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  96 |           0.468522 |            -0.212394   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  97 |           0.468522 |            -0.114982   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  98 |           0.468522 |            -0.29775    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# |  99 |           0.468522 |            -0.380255   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 100 |           0.468522 |            -0.377558   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 101 |           0.468522 |            -0.330679   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 102 |           0.468522 |            -0.185049   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 103 |           0.468522 |            -0.330679   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 104 |           0.468522 |            -0.330679   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 105 |           0.468522 |             0.16612    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 106 |           0.468522 |             0.375764   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 107 |           0.468522 |            -0.380777   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 108 |           0.468522 |            -0.373819   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 109 |           0.468522 |             0.95098    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 110 |           0.468522 |             0.970463   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 111 |           0.468522 |             0.286789   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 112 |           0.468522 |             2.06899    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 113 |           0.468522 |             0.105064   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 114 |           0.468522 |            -0.380255   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 115 |           0.468521 |            -0.0526557  |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 116 |           0.468521 |            -0.177795   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 117 |           0.468521 |            -0.406486   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 118 |           0.468521 |            -0.320155   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 119 |           0.468521 |            -0.403581   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 120 |           0.468521 |            -0.377558   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 121 |           0.468521 |            -0.396693   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 122 |           0.468521 |            -0.406825   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 123 |           0.468521 |            -0.406652   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 124 |           0.468521 |            -0.393823   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 125 |           0.468521 |            -0.40259    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 126 |           0.468521 |             0.372077   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 127 |           0.468521 |            -0.386552   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 128 |           0.468521 |             2.83464    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 129 |           0.468521 |            -0.329288   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 130 |           0.468521 |            -0.396084   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 131 |           0.468521 |            -0.340246   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 132 |           0.468521 |            -0.364912   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 133 |           0.468521 |            -0.160957   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 134 |           0.468521 |             0.510123   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 135 |           0.468521 |            -0.258816   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 136 |           0.468521 |            -0.400537   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 137 |           0.468521 |            -0.39504    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 138 |           0.468521 |            -0.399389   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 139 |           0.468521 |            -0.295889   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 140 |           0.468521 |            -0.405999   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 141 |           0.468521 |            -0.0526384  |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 142 |           0.468521 |            -0.154773   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 143 |           0.468521 |             0.0135233  |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 144 |           0.468521 |             0.30528    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 145 |           0.468521 |            -0.272841   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 146 |           0.468521 |            -0.348979   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 147 |           0.468521 |             0.0125448  |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 148 |           0.468521 |             0.0158281  |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 149 |           0.468521 |            -0.195694   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 150 |           0.468521 |            -0.296411   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 151 |           0.468521 |            -0.306883   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 152 |           0.468521 |            -0.269579   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 153 |           0.468521 |             0.0422511  |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 154 |           0.468521 |            -0.374184   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 155 |           0.468521 |            -0.359503   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 156 |           0.468521 |            -0.377506   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 157 |           0.468521 |            -0.368374   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 158 |           0.468521 |            -0.390909   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 159 |           0.468521 |            -0.405586   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 160 |           0.468521 |             0.358922   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 161 |           0.468521 |            -0.384082   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 162 |           0.468521 |            -0.179656   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 163 |           0.468521 |            -0.341007   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 164 |           0.468521 |             1.89059    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 165 |           0.468521 |            -0.360946   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 166 |           0.468521 |            -0.40102    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 167 |           0.468521 |             0.605865   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 168 |           0.468521 |            -0.328383   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 169 |           0.468521 |            -0.135577   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 170 |           0.468521 |            -0.155895   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 171 |           0.468521 |            -0.406643   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 172 |           0.468521 |            -0.389278   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 173 |           0.468521 |            -0.161861   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 174 |           0.468521 |            -0.367426   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 175 |           0.468521 |            -0.157843   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 176 |           0.468521 |             4.93206    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 177 |           0.468521 |            -0.259116   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 178 |           0.468522 |            -0.406238   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 179 |           0.468522 |            -0.377558   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 180 |           0.468522 |            -0.39765    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 181 |           0.468522 |            -0.379942   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 182 |           0.468522 |            -0.13553    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 183 |           0.468522 |            -0.400537   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 184 |           0.468522 |            -0.284756   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 185 |           0.468522 |            -0.247827   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 186 |           0.468522 |            -0.402625   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 187 |           0.468522 |            -0.383873   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 188 |           0.468522 |            -0.371992   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 189 |           0.468522 |            -0.35378    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 190 |           0.468522 |            -0.406486   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 191 |           0.468522 |             2.22012    |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 192 |           0.468522 |            -0.406238   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 193 |           0.468522 |            -0.293063   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 194 |           0.468522 |            -0.321982   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 195 |           0.468522 |            -0.401372   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 196 |           0.468522 |            -0.160383   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 197 |           0.468522 |            -0.218482   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 198 |           0.468522 |            -0.406643   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# | 199 |           0.468522 |            -0.119852   |              1.42109e-16 |                  1.77636e-17 |                             1 |            1 |
# +-----+--------------------+------------------------+--------------------------+------------------------------+-------------------------------+--------------+

# %%
# Declaramos un dataframe de ejemplo con el que trabajar
df = pd.DataFrame({
    "valores_aleatorios" : np.random.randint(20 , 50, size=10)
})


# Calculo de minimos, maximos y percentiles con pandas 
print('-' * 30)
print("Valores aleatorios")
print("Mínimo: ", df["valores_aleatorios"].min())
print("Máximo: ", df["valores_aleatorios"].max())
print("Percentil 25: ", df["valores_aleatorios"].quantile(0.25))
print("Percentil 50: ", df["valores_aleatorios"].quantile(0.50))
print("Percentil 80: ", df["valores_aleatorios"].quantile(0.80))


# APLICAR UNA FUNCIÓN A UNA COLUMNA
def clasificar_valores(valor):
    if valor < 25:
        return "Bajo"
    elif valor < 35:
        return "Medio"
    else:
        return "Alto"

df["valores_clasificados"] = df["valores_aleatorios"].apply(clasificar_valores)

# Clasificar los datos en categorías según los percentiles

print(tabulate(df, headers="keys", tablefmt="psql"))
# Out:
# ------------------------------
# Valores aleatorios
# Mínimo:  20
# Máximo:  48
# Percentil 25:  31.0
# Percentil 50:  40.5
# Percentil 80:  44.2
# +----+----------------------+------------------------+
# |    |   valores_aleatorios | valores_clasificados   |
# |----+----------------------+------------------------|
# |  0 |                   48 | Alto                   |
# |  1 |                   40 | Alto                   |
# |  2 |                   42 | Alto                   |
# |  3 |                   20 | Bajo                   |
# |  4 |                   22 | Bajo                   |
# |  5 |                   37 | Alto                   |
# |  6 |                   44 | Alto                   |
# |  7 |                   29 | Medio                  |
# |  8 |                   41 | Alto                   |
# |  9 |                   45 | Alto                   |
# +----+----------------------+------------------------+
